# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

import torch
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# %%
dataset_path = "../datasets/raw/chest_xray"

train_path = os.path.join(dataset_path, "train")
val_path = os.path.join(dataset_path, "val")
test_path = os.path.join(dataset_path, "test")

print(train_path)
print(val_path)
print(test_path)
# Out:
# ../datasets/raw/chest_xray\train
# ../datasets/raw/chest_xray\val
# ../datasets/raw/chest_xray\test

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# %%
dataset_path = "datasets/raw/chest_xray"

train_path = os.path.join(dataset_path, "train")
val_path = os.path.join(dataset_path, "val")
test_path = os.path.join(dataset_path, "test")

print(train_path)
print(val_path)
print(test_path)
# Out:
# datasets/raw/chest_xray\train
# datasets/raw/chest_xray\val
# datasets/raw/chest_xray\test

# %%
import os

print(os.listdir("../datasets/raw/chest_xray/train"))
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
print(os.listdir("../datasets/raw/chest_xray/train/NORMAL")[:10])
# Out:
# ['.DS_Store', 'IM-0115-0001.jpeg', 'IM-0117-0001.jpeg', 'IM-0119-0001.jpeg', 'IM-0122-0001.jpeg', 'IM-0125-0001.jpeg', 'IM-0127-0001.jpeg', 'IM-0128-0001.jpeg', 'IM-0129-0001.jpeg', 'IM-0131-0001.jpeg']

# %%
print(os.listdir("../datasets/raw/chest_xray/train/PNEUMONIA")[:10])
# Out:
# ['.DS_Store', 'person1000_bacteria_2931.jpeg', 'person1000_virus_1681.jpeg', 'person1001_bacteria_2932.jpeg', 'person1002_bacteria_2933.jpeg', 'person1003_bacteria_2934.jpeg', 'person1003_virus_1685.jpeg', 'person1004_bacteria_2935.jpeg', 'person1004_virus_1686.jpeg', 'person1005_bacteria_2936.jpeg']

# %%
import os

print(os.listdir("../datasets/raw/chest_xray/train/NORMAL")[:5])
print(os.listdir("../datasets/raw/chest_xray/train/PNEUMONIA")[:5])
# Out:
# ['IM-0115-0001.jpeg', 'IM-0117-0001.jpeg', 'IM-0119-0001.jpeg', 'IM-0122-0001.jpeg', 'IM-0125-0001.jpeg']
# ['person1000_bacteria_2931.jpeg', 'person1000_virus_1681.jpeg', 'person1001_bacteria_2932.jpeg', 'person1002_bacteria_2933.jpeg', 'person1003_bacteria_2934.jpeg']

# %%
import os

print(os.path.exists("../datasets/raw/chest_xray/train"))
print(os.path.exists("../datasets/raw/chest_xray/val"))
print(os.path.exists("../datasets/raw/chest_xray/test"))
# Out:
# True
# True
# True

# %%
print(train_path)
print(val_path)
print(test_path)
# Out:
# datasets/raw/chest_xray\train
# datasets/raw/chest_xray\val
# datasets/raw/chest_xray\test

# %%
from torchvision.datasets import ImageFolder

train_dataset = ImageFolder(train_path, transform=train_transform)
val_dataset = ImageFolder(val_path, transform=test_transform)
test_dataset = ImageFolder(test_path, transform=test_transform)

print("Train:", len(train_dataset))
print("Validation:", len(val_dataset))
print("Test:", len(test_dataset))
print(train_dataset.classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 from torchvision.datasets import ImageFolder
#       2
# ----> 3 train_dataset = ImageFolder(train_path, transform=train_transform)
#       4 val_dataset = ImageFolder(val_path, transform=test_transform)
#       5 test_dataset = ImageFolder(test_path, transform=test_transform)
#       6
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torchvision\datasets\folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
# ...

# %%
print("dataset_path =", dataset_path)
print("train_path =", train_path)
print("val_path =", val_path)
print("test_path =", test_path)
# Out:
# dataset_path = datasets/raw/chest_xray
# train_path = datasets/raw/chest_xray\train
# val_path = datasets/raw/chest_xray\val
# test_path = datasets/raw/chest_xray\test

# %%
import os

dataset_path = "../datasets/raw/chest_xray"

train_path = os.path.join(dataset_path, "train")
val_path = os.path.join(dataset_path, "val")
test_path = os.path.join(dataset_path, "test")

print(dataset_path)
print(train_path)
# Out:
# ../datasets/raw/chest_xray
# ../datasets/raw/chest_xray\train

# %%
from torchvision.datasets import ImageFolder

train_dataset = ImageFolder(train_path, transform=train_transform)

# %%
from torchvision.datasets import ImageFolder

train_dataset = ImageFolder(
    train_path,
    transform=train_transform
)

val_dataset = ImageFolder(
    val_path,
    transform=test_transform
)

test_dataset = ImageFolder(
    test_path,
    transform=test_transform
)

# %%
print("Train Images:", len(train_dataset))
print("Validation Images:", len(val_dataset))
print("Test Images:", len(test_dataset))

print(train_dataset.classes)
print(train_dataset.class_to_idx)
# Out:
# Train Images: 5216
# Validation Images: 16
# Test Images: 624
# ['NORMAL', 'PNEUMONIA']
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
print(train_path)
print(val_path)
print(test_path)
# Out:
# ../datasets/raw/chest_xray\train
# ../datasets/raw/chest_xray\val
# ../datasets/raw/chest_xray\test

# %%
from torchvision.datasets import ImageFolder

train_dataset = ImageFolder(train_path, transform=train_transform)
print("Train dataset created successfully!")
# Out:
# Train dataset created successfully!

# %%
val_dataset = ImageFolder(val_path, transform=test_transform)
print("Validation dataset created successfully!")
# Out:
# Validation dataset created successfully!

# %%
test_dataset = ImageFolder(test_path, transform=test_transform)
print("Test dataset created successfully!")
# Out:
# Test dataset created successfully!

# %%
print("Train Images:", len(train_dataset))
print("Validation Images:", len(val_dataset))
print("Test Images:", len(test_dataset))

print(train_dataset.classes)
print(train_dataset.class_to_idx)
# Out:
# Train Images: 5216
# Validation Images: 16
# Test Images: 624
# ['NORMAL', 'PNEUMONIA']
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
from torch.utils.data import DataLoader

batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
print("Train batches:", len(train_loader))
print("Validation batches:", len(val_loader))
print("Test batches:", len(test_loader))
# Out:
# Train batches: 163
# Validation batches: 1
# Test batches: 20

# %%
images, labels = next(iter(train_loader))

print("Image Batch Shape :", images.shape)
print("Label Batch Shape :", labels.shape)
# Out:
# Image Batch Shape : torch.Size([32, 3, 224, 224])
# Label Batch Shape : torch.Size([32])

# %%
import matplotlib.pyplot as plt

class_names = train_dataset.classes

plt.figure(figsize=(12, 6))

for i in range(6):
    plt.subplot(2, 3, i + 1)

    img = images[i].permute(1, 2, 0)

    img = img * 0.5 + 0.5

    plt.imshow(img)

    plt.title(class_names[labels[i]])

    plt.axis("off")

plt.show()
